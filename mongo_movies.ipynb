# %%
import pandas as pd
import numpy as np
import json
from pprint import pprint

# %%
from pymongo import MongoClient

# %%
from copy import deepcopy

# %%
client = MongoClient()

# %%
list(client.list_databases())
# Out:
# [{'name': 'admin', 'sizeOnDisk': 32768.0, 'empty': False},
#  {'name': 'config', 'sizeOnDisk': 73728.0, 'empty': False},
#  {'name': 'local', 'sizeOnDisk': 73728.0, 'empty': False},
#  {'name': 'movies', 'sizeOnDisk': 117374976.0, 'empty': False}]

# %%
db = client.movies
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'movies')

# %%
db.list_collection_names()
# Out:
# ['movies']

# %%
movies = db.movies
movies
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'movies'), 'movies')

# %%
movies.find_one()
# Out:
# {'_id': ObjectId('5e4ef8ff7a577357a4db83c3'),
#  'wikipedia_id': 975900,
#  'freebase_id': '/m/03vyhn',
#  'title': 'Ghosts of Mars',
#  'release_date': '2001-08-24',
#  'box_office_revenue': 14010832.0,
#  'runtime': 98.0,
#  'languages': ['English Language'],
#  'countries': ['United States of America'],
#  'genres': ['Thriller',
#   'Science Fiction',
#   'Horror',
#   'Adventure',
#   'Supernatural',
#   'Action',
#   'Space western'],
#  'summary': 'Set in the second half of the 22nd century, the film depicts Mars as a planet that has been 84% terraformed, allowing humans to walk on the surface without wearing pressure suits. The Martian society has become largely matriarchal, with women in most positions of authority. The story concerns a police officer, Melanie Ballard , second in command of a small team alongside Sergeant Jericho  sent to pick up and transport a prisoner named Desolation Williams . Arriving at the remote mining town where Williams is being held, Ballard finds virtually all of the people missing. She learns that the miners had discovered an underground doorway created by an ancient Martian civilization. When the door was opened it released "ghosts," disembodied spirits which possessed the miners. Violence ensues, as the possessed miners commit horrific acts of death and destruction, as well as self-mutilation. With their team leader Helena Bradock  murdered, Ballard must fight off the attacking miners, escape the town, and destroy the ghosts, if possible. Unfortunately, her intentions are complicated by the fact that killing a possessed human merely releases the Martian spirit to possess another human. The team eventually decides to blow up a nuclear reactor to try and vaporize all of the ghosts. At several points in the film Sergeant Jericho shows a romantic interest in Ballard, mostly unreciprocated. Ballard\'s crew along with survivors who manage to gather in the jail are eventually wiped out by the miners after many fierce battles and events , leaving only her and Williams after Sergeant Jericho and the other remaining officers and the two operators of the train are killed upon returning from a brief retreat to finish the fight. Not wanting the authorities to blame the massacre on him, he handcuffs Ballard to her cot and escapes from the train, leaving her to return home and deliver her report, which is received with skepticism by her superiors. While Ballard recuperates at a hospital, the released spirits, who weren\'t destroyed after all, attack the city. The end scene sets the movie up for a sequel as Williams returns to team up with Ballard to fight the possessed.'}

# %%
movies.count_documents({})
# Out:
# 81840

# %%
test = movies.find_one()
test
# Out:
# {'_id': ObjectId('5e4ef8ff7a577357a4db83c3'),
#  'wikipedia_id': 975900,
#  'freebase_id': '/m/03vyhn',
#  'title': 'Ghosts of Mars',
#  'release_date': '2001-08-24',
#  'box_office_revenue': 14010832.0,
#  'runtime': 98.0,
#  'languages': ['English Language'],
#  'countries': ['United States of America'],
#  'genres': ['Thriller',
#   'Science Fiction',
#   'Horror',
#   'Adventure',
#   'Supernatural',
#   'Action',
#   'Space western'],
#  'summary': 'Set in the second half of the 22nd century, the film depicts Mars as a planet that has been 84% terraformed, allowing humans to walk on the surface without wearing pressure suits. The Martian society has become largely matriarchal, with women in most positions of authority. The story concerns a police officer, Melanie Ballard , second in command of a small team alongside Sergeant Jericho  sent to pick up and transport a prisoner named Desolation Williams . Arriving at the remote mining town where Williams is being held, Ballard finds virtually all of the people missing. She learns that the miners had discovered an underground doorway created by an ancient Martian civilization. When the door was opened it released "ghosts," disembodied spirits which possessed the miners. Violence ensues, as the possessed miners commit horrific acts of death and destruction, as well as self-mutilation. With their team leader Helena Bradock  murdered, Ballard must fight off the attacking miners, escape the town, and destroy the ghosts, if possible. Unfortunately, her intentions are complicated by the fact that killing a possessed human merely releases the Martian spirit to possess another human. The team eventually decides to blow up a nuclear reactor to try and vaporize all of the ghosts. At several points in the film Sergeant Jericho shows a romantic interest in Ballard, mostly unreciprocated. Ballard\'s crew along with survivors who manage to gather in the jail are eventually wiped out by the miners after many fierce battles and events , leaving only her and Williams after Sergeant Jericho and the other remaining officers and the two operators of the train are killed upon returning from a brief retreat to finish the fight. Not wanting the authorities to blame the massacre on him, he handcuffs Ballard to her cot and escapes from the train, leaving her to return home and deliver her report, which is received with skepticism by her superiors. While Ballard recuperates at a hospital, the released spirits, who weren\'t destroyed after all, attack the city. The end scene sets the movie up for a sequel as Williams returns to team up with Ballard to fight the possessed.'}

# %%
# Out:
# True

# %%
list(test['languages'].values())

# %%
for m in movies.find({}):
    updates = {}
    
    if "languages" in m and isinstance(m['languages'],dict):
        updates['languages'] = list(m['languages'].values())
        
    if "countries" in m and isinstance(m['countries'],dict):
        updates['countries'] = list(m['countries'].values())
        
    if "genres" in m and isinstance(m['genres'],dict):
        updates['genres'] = list(m['genres'].values())
    if len(updates):
        movies.update_one(
            {"_id": m['_id']},
            {"$set": updates}
        )

# %%
print("%% w/ languages: %.5f" % (movies.count_documents({"languages":{"$exists":True}}) / movies.count_documents({})))
print("%% w/ countries: %.5f" % (movies.count_documents({"countries":{"$exists":True}}) / movies.count_documents({})))
print("%% w/ genres:    %.5f" % (movies.count_documents({"genres":{"$exists":True}}) / movies.count_documents({})))
# Out:
# % w/ languages: 0.99879
# % w/ countries: 0.99879
# % w/ genres:    0.99879

# %%
list(movies.find({"languages":{"$exists":False}}))
# Out:
# [{'_id': ObjectId('5e4efda326d8a3264deeb769'),
#   'wikipedia_id': 2862137,
#   'summary': 'Sathyanarayan Murthy  is a rough but kind man who lives in Amalapuram with his niece, mother, sister and her husband. Sathya and his niece Lavanya share a special bond and are the best of friends. One day, Lavanya dies while playing on the swing. Sathya later finds out that she has been murdered by gun dealer Raj Malhotra ([[Arbaaz Khan . He meets and falls in love with Shilaza . Sathyanarayan challenges Raj Malhotra and wants to go the US but cannot get a permanent visa because he was not educated. He meets and marries Neelu , then goes to the US and kills Malhotra.'},
#  {'_id': ObjectId('5e4efdad26d8a3264deeb8a1'),
#   'wikipedia_id': 33334420,
munks burn a hole in Mickey\'s boot with a match. Mickey assumes that Pluto is to blame and scolds him. Mickey remains unaware of the chipmunks throughout the film. After Mickey leaves to get more wood, Pluto chases Chip and Dale across the room. They lead Pluto across a table and mantle above the fireplace. Pluto accidentally gets his nose stuck in the muzzle of Mickey\'s rifle which is hanging over the fireplace. As Pluto tries to pull is nose free, he realizes that one of the hooks on which the rifle is mounted is directly in front of the trigger; the more Pluto pulls the more he will cause the gun to go off in his face. Gradually the table which Pluto is standing on with his hind paws starts to slide back. Pluto falls and makes the rifle fire, but rifle\'s delay is just long enough that Pluto narrowly avoids the bullet. Pluto lands on the floor where the rifle hits him on the head momentarily knocking him unconscious. From the table above Chip and Dale pour ketchup over the dog to make it look as if he is seriously wounded. Suddenly Mickey returns having heard the gunshot, and when he sees Pluto he thinks he is dead. Pluto comes to and first starts to comfort Mickey. But when he sees the ketchup he starts to panic. Mickey hurriedly carries him off to find help. Thus Chip and Dale regain working ownership over the property.This transfer of ownership is the reference of the film\'s title "squatter\'s rights" which is a form of adverse possession.'},
#  {'_id': ObjectId('5e4efeaa26d8a3264deedfac'),
#   'wikipedia_id': 12651534,
#   'summary': "Home to just 12% of the world's population, Sub-Saharan Africa is home to over 60% of all people living with HIV. Birchall journeys to Eastern Africa to investigate the true horror of living in countries beneath the poverty line, we realize the one thing that we share despite our many differences is the fact that we are all human. As such, our role is clear: to help each other. This is the story of a continent in disarray; how a storm of a different kind is affecting our world. This is Africa."},
#  {'_id': ObjectId('5e4efeaa26d8a3264deedfb1'),
#   'wikipedia_id': 28278467,
#   'summary': "The story of a man who's had a successful film career but since falling on hard times can only find employment working in the adult entertainment industry as a means to provide for his family. Based on a true story, My Trip to the Dark Side is one man’s journey traveling from the pinnacle of a Hollywood career, which takes an unexpected turn into the dark and deceptive world of the adult entertainment industry. See the sequel My Trip Back to the Dark Side.  *Jason Pace - Shawn Stone *Ryan Judd - Jacob Stevens *Brienne De Beau - Emily Stone *Sean Kanan - David Prince *Alisa Reyes - Misty Rae *Courtney Gains - Bobby G. *Krizia Bajos - Lisa DeAngelo *Kathy Christopherson - Kelly Thompson *Ron Masak - James Griffin"},
#  {'_id': ObjectId('5e4efeb226d8a3264deee0f4'),
#   'wikipedia_id': 21366668,
#   'summary': 'Nair-san lived from 1905 to 1990. His father was a Tamil Brahmin and mother was a Nair. He was born and did his schooling in Trivandrum, Kerala. During school days Nair-san and his friends fought against the British rule in India. So he was forced to leave India to Japan and continued the fight against British rule there.IndiaGlitz , "Mohanlal in a Japanese film", accessed 02-09-2009 For his service to the Japanese people Nair-san later obtained a civilian merit from Japan, The Order of the Sacred Treasure .Rediff.com , "Jackie chan wont be part of this film", accessed 02-09-2009'},
#  {'_id': ObjectId('5e4efebb26d8a3264deee234'),
#   'wikipedia_id': 31642366,
# ...
#  {'_id': ObjectId('5e4f019926d8a3264def4c27'),
#   'wikipedia_id': 491329,
basis of unsubstantiated nitroglycerine traces, and the four, including Gerry, are sentenced to long terms of imprisonment. His time in prison shows a progression from a bitter son who rails at his father to an awakening when he discovers the real perpetrator of the bombing in the same facility. When this man leads a prison protest and then sets a hated prison guard on fire, Gerry is the one who saves the man with a blanket. Gerry takes over the fight for justice himself when his father dies in custody. A campaigning lawyer  who has been investigating the case on behalf of Giuseppe in the wake of public campaigns demanding the release of the accused has a break when she tries to access his father\'s file and is able to look instead at Gerry\'s, finding that vital police documents in the file are marked "Not to be shown to the Defence". During the course of their appeal, the production of these documents leads to a triumphant scene in court when she produces the evidence that the police officers have been lying all the way through, which leads to the exoneration and release of all the Four.'},
#  {'_id': ObjectId('5e4f01db26d8a3264def5741'),
#   'wikipedia_id': 34076714,
#   'summary': 'After a hit gone wrong, Nikita, an exiled Russian assassin, takes Zoe, a defected American libertine, on a sexually charged journey across the old Eastern Bloc in search of refuge and freedom. Pusuing them and intent on capture are members of eastern and western governments, the military-industrial complex, a private paramilitary group and a squad of South Slavic mercenaries. The hunt, however, is not what it seems as a revelation from Nikita changes a simple getaway into a potential catastrophic event that threatens the modern world and could lead to the annihilation of liberty.'},
#  {'_id': ObjectId('5e4f01ec26d8a3264def5a41'),
#   'wikipedia_id': 8030673,
#   'summary': "Gopinatha Menon ([[Dileep  a.k.a. Gopi is a young engineer staying alone in a flat in Thiruvananthapuram city. One day he was found dead by hanging. His fiancée Renuka  wants to know the cause of his suicide and decides to do a bit of investigation. She meets different people who had some role in Gopi's life and gets to hear their versions about Gopi. All their testimonials lead to her concluding on what Gopi's reasons were. The ideal attitude that Gopi possess against the odds provides the fuel for Renuka's journey. As Renuka gets more closer to knowing Gopi, the man who led a very normal life posed an even more difficult question as to the cause of his death. Finally she understands that Gopi committed suicide out of the shame of being alive in such a merciless society. The director successfully portrays different evils in the society and the film, in its course way beyond a regional movie as it embeds different cultures. The film is also for the way the story is told, the Rashomon way."}]

# %%
def avg(vals):
    i = 0
    total = 0
    for v in vals:
        i += 1
        total += v
    if i > 0:
        return total / i
    else:
        return None

print("Maximum summary length (in characters)",max(map(
    lambda e: e['summary_length'],
    movies.aggregate([
    {
      "$match": {
          "summary": {"$exists":True}
      }  
    },
    {
        "$project":{
            "summary_length": { "$strLenCP": "$summary" }
        }
    }
]))))
print("Average summary length (in characters)",avg(map(
    lambda e: e['summary_length'],
    movies.aggregate([
    {
      "$match": {
          "summary": {"$exists":True}
      }  
    },
    {
        "$project":{
            "summary_length": { "$strLenCP": "$summary" }
        }
    }
]))))
print("Minimum summary length (in characters)",min(map(
    lambda e: e['summary_length'],
    movies.aggregate([
    {
      "$match": {
          "summary": {"$exists":True}
      }  
    },
    {
        "$project":{
            "summary_length": { "$strLenCP": "$summary" }
        }
    }
]))))
# Out:
# Maximum summary length (in characters) 28159
# Average summary length (in characters) 1784.0342292508806
# Minimum summary length (in characters) 99

# %% [markdown]
# ***
#
# Now let's try to analyze the summaries

# %%
movies.count_documents({"summary":{"$exists":False}})
# Out:
# 39537

# %%
movies.find_one({})
# Out:
# {'_id': ObjectId('5e4ef8ff7a577357a4db83c3'),
#  'wikipedia_id': 975900,
#  'freebase_id': '/m/03vyhn',
#  'title': 'Ghosts of Mars',
#  'release_date': '2001-08-24',
#  'box_office_revenue': 14010832.0,
#  'runtime': 98.0,
#  'languages': ['English Language'],
#  'countries': ['United States of America'],
#  'genres': ['Thriller',
#   'Science Fiction',
#   'Horror',
#   'Adventure',
#   'Supernatural',
#   'Action',
#   'Space western'],
#  'summary': 'Set in the second half of the 22nd century, the film depicts Mars as a planet that has been 84% terraformed, allowing humans to walk on the surface without wearing pressure suits. The Martian society has become largely matriarchal, with women in most positions of authority. The story concerns a police officer, Melanie Ballard , second in command of a small team alongside Sergeant Jericho  sent to pick up and transport a prisoner named Desolation Williams . Arriving at the remote mining town where Williams is being held, Ballard finds virtually all of the people missing. She learns that the miners had discovered an underground doorway created by an ancient Martian civilization. When the door was opened it released "ghosts," disembodied spirits which possessed the miners. Violence ensues, as the possessed miners commit horrific acts of death and destruction, as well as self-mutilation. With their team leader Helena Bradock  murdered, Ballard must fight off the attacking miners, escape the town, and destroy the ghosts, if possible. Unfortunately, her intentions are complicated by the fact that killing a possessed human merely releases the Martian spirit to possess another human. The team eventually decides to blow up a nuclear reactor to try and vaporize all of the ghosts. At several points in the film Sergeant Jericho shows a romantic interest in Ballard, mostly unreciprocated. Ballard\'s crew along with survivors who manage to gather in the jail are eventually wiped out by the miners after many fierce battles and events , leaving only her and Williams after Sergeant Jericho and the other remaining officers and the two operators of the train are killed upon returning from a brief retreat to finish the fight. Not wanting the authorities to blame the massacre on him, he handcuffs Ballard to her cot and escapes from the train, leaving her to return home and deliver her report, which is received with skepticism by her superiors. While Ballard recuperates at a hospital, the released spirits, who weren\'t destroyed after all, attack the city. The end scene sets the movie up for a sequel as Williams returns to team up with Ballard to fight the possessed.'}

# %%
next(movies.find({},{"_id":0,"wikipedia_id":1,"summary":1,"title":1}))
# Out:
# {'wikipedia_id': 975900,
#  'title': 'Ghosts of Mars',
#  'summary': 'Set in the second half of the 22nd century, the film depicts Mars as a planet that has been 84% terraformed, allowing humans to walk on the surface without wearing pressure suits. The Martian society has become largely matriarchal, with women in most positions of authority. The story concerns a police officer, Melanie Ballard , second in command of a small team alongside Sergeant Jericho  sent to pick up and transport a prisoner named Desolation Williams . Arriving at the remote mining town where Williams is being held, Ballard finds virtually all of the people missing. She learns that the miners had discovered an underground doorway created by an ancient Martian civilization. When the door was opened it released "ghosts," disembodied spirits which possessed the miners. Violence ensues, as the possessed miners commit horrific acts of death and destruction, as well as self-mutilation. With their team leader Helena Bradock  murdered, Ballard must fight off the attacking miners, escape the town, and destroy the ghosts, if possible. Unfortunately, her intentions are complicated by the fact that killing a possessed human merely releases the Martian spirit to possess another human. The team eventually decides to blow up a nuclear reactor to try and vaporize all of the ghosts. At several points in the film Sergeant Jericho shows a romantic interest in Ballard, mostly unreciprocated. Ballard\'s crew along with survivors who manage to gather in the jail are eventually wiped out by the miners after many fierce battles and events , leaving only her and Williams after Sergeant Jericho and the other remaining officers and the two operators of the train are killed upon returning from a brief retreat to finish the fight. Not wanting the authorities to blame the massacre on him, he handcuffs Ballard to her cot and escapes from the train, leaving her to return home and deliver her report, which is received with skepticism by her superiors. While Ballard recuperates at a hospital, the released spirits, who weren\'t destroyed after all, attack the city. The end scene sets the movie up for a sequel as Williams returns to team up with Ballard to fight the possessed.'}

# %%
summary_df = pd.DataFrame(movies.find({"summary":{"$exists":True}},{"_id":0,"wikipedia_id":1,"summary":1,"title":1}))
summary_df = summary_df[["wikipedia_id","title","summary"]]
summary_df.head()
# Out:
#    wikipedia_id                      title  \
# 0        975900             Ghosts of Mars
# 1       9363483           White Of The Eye
# 2        261236          A Woman in Flames
# 3      18998739  The Sorcerer's Apprentice
# 4       6631279                Little city
#
#                                              summary
# 0  Set in the second half of the 22nd century, th...
# 1  A series of murders of rich young women throug...
# 2  Eva, an upper class housewife, becomes frustra...
# 3  Every hundred years, the evil Morgana  returns...
# 4  Adam, a San Francisco-based artist who works a...

# %%
summary_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42303 entries, 0 to 42302
# Data columns (total 3 columns):
# wikipedia_id    42303 non-null int64
# title           42204 non-null object
# summary         42303 non-null object
# dtypes: int64(1), object(2)
# memory usage: 991.6+ KB

# %%
import string

import nltk
from nltk.stem import SnowballStemmer
from nltk.tokenize import word_tokenize

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA, NMF, LatentDirichletAllocation

# %%
ls
# Out:
# data/                   movie_lens_setup.ipynb  pickles/
# mongo_movies.ipynb      names.csv               x_ideas/
# movie_data_eda.ipynb    names.json

# %%
with open("names.json") as f:
    name_list = json.loads(f.read())
name_list[:5]
# Out:
# ['aaban', 'aabha', 'aabid', 'aabriella', 'aadam']

# %%
"–" in string.punctuation
# Out:
# False

# %%
letters = list("abcdefg")
n = 4
for i in range(len(letters)-n+1):
    print(" ".join(letters[i:i+n]))
# Out:
# a b c d
# b c d e
# c d e f
# d e f g

# %%
import re

# %%
re.sub(r"[^\w\s]",""," Test 123 - ' a,.'").strip()
# Out:
# 'Test 123   a'

# %%
r = re.compile(r"[^\w\s]")
r
# Out:
# re.compile(r'[^\w\s]', re.UNICODE)

# %%
r.sub(""," Test 123 - ' a,.'").strip()
# Out:
# 'Test 123   a'

# %%
class WordCleaner:
    def __init__(self,ngram_range=(1,1)):
        self.ngram_range = ngram_range
        self.stemmer = SnowballStemmer("english")
        self.stop_words = set(nltk.corpus.stopwords.words("english"))
        self.names = set(name_list)
        self.punctuation = set(string.punctuation).union({"’","–","“","”","—","—"})
        self.digits = set(string.digits)
        
        self.BAD_CHARS = re.compile(r"[^\w\s]")
        self.EXTRA_SPACE = re.compile(r"\s+")
        return
    
    def __call__(self,text):
        return list(self.to_ngram(text))
    
    def sent_gen(self,text):
        for w in nltk.word_tokenize(text):
            w = self.BAD_CHARS.sub("",w).strip()
            w = self.EXTRA_SPACE.sub(" ",w)
            if w in self.stop_words or w in self.names: 
                continue
            sw = self.stemmer.stem(w)
            if sw in self.stop_words or w in self.names: 
                continue
            if not w: continue
            yield sw
    
    def to_ngram(self,text):
        ng_start, ng_end = self.ngram_range
        words = list(self.sent_gen(text))
        for n in range(ng_start,ng_end+1):
            for ng in self.make_ngram(words,n):
                yield ng
    
    def make_ngram(self,word_list,n):
        for i in range(len(word_list)-(n-1)):
            yield " ".join(word_list[i:i+n])
            
wc = WordCleaner((1,1))
wc(summary_df['summary'][0])[-10:]
# Out:
# ['wrong',
#  'year',
#  'year ago',
#  'year later',
#  'year old',
#  'yearold',
#  'yet',
#  'youth',
#  'zombi',
#  '—']

# %%
tfidf = TfidfVectorizer(
    tokenizer=wc,
    max_features=1000
)
tfidf_summ = tfidf.fit_transform(summary_df['summary'])
tfidf_summ
# Out:
# <42303x1000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2570625 stored elements in Compressed Sparse Row format>

# %%
tfidf.vocabulary_
# Out:
# {'second': 759,
#  'half': 396,
#  'film': 335,
#  'planet': 631,
#  'allow': 31,
#  'human': 426,
#  'walk': 950,
#  'without': 977,
#  'wear': 959,
#  'suit': 849,
#  'societi': 810,
#  'becom': 90,
#  'larg': 480,
#  'women': 979,
#  'posit': 644,
#  'author': 76,
#  'concern': 187,
#  'polic': 638,
#  'polic offic': 639,
#  'offic': 584,
#  'command': 179,
#  'small': 807,
#  'team': 871,
#  'sent': 770,
#  'pick': 625,
#  'transport': 906,
#  'prison': 656,
#  'name': 558,
#  'arriv': 61,
#  'mine': 539,
#  'town': 902,
#  'held': 404,
#  'find': 339,
#  'peopl': 617,
#  'miss': 542,
#  'learn': 488,
#  'discov': 257,
#  'creat': 214,
#  'door': 264,
#  'open': 592,
#  'releas': 703,
#  'ghost': 373,
#  'possess': 645,
#  'ensu': 294,
#  'commit': 180,
#  'act': 9,
#  'death': 233,
#  'well': 963,
#  'leader': 487,
#  'murder': 555,
#  'must': 556,
#  'fight': 332,
#  'attack': 69,
#  'escap': 297,
#  'destroy': 247,
#  'possibl': 646,
#  'unfortun': 930,
#  'intent': 451,
#  'fact': 320,
#  'kill': 470,
#  'anoth': 45,
#  'eventu': 300,
#  'decid': 234,
#  'blow': 109,
#  'tri': 911,
#  'sever': 779,
#  'point': 636,
#  'show': 789,
#  'romant': 740,
#  'interest': 452,
#  'along': 34,
#  'survivor': 856,
#  'manag': 517,
#  'jail': 461,
#  'event': 299,
#  'leav': 489,
#  'remain': 705,
#  'two': 921,
#  'oper': 593,
#  'train': 904,
#  'upon': 934,
#  'return': 726,
#  'brief': 119,
#  'finish': 340,
#  'want': 952,
#  'blame': 106,
#  'return home': 727,
#  'home': 416,
#  'deliv': 239,
#  'report': 712,
#  'receiv': 694,
#  'hospit': 419,
#  'nt': 577,
#  'citi': 162,
#  'end': 287,
#  'scene': 753,
#  'set': 777,
#  'movi': 552,
#  'seri': 773,
#  'throughout': 887,
#  'killer': 471,
#  'lead': 486,
#  'detect': 248,
#  'visit': 945,
#  'sound': 814,
#  'system': 861,
#  'make': 516,
#  'air': 27,
#  'head': 402,
#  'come': 177,
#  'room': 741,
#  'marri': 519,
#  'year': 991,
#  'earlier': 276,
#  'seduc': 762,
#  'away': 79,
#  'boyfriend': 117,
#  'question': 680,
#  'husband': 428,
#  'involv': 459,
#  'various': 939,
#  'flashback': 345,
#  'previous': 655,
#  'relationship': 702,
#  'later': 483,
#  'explain': 311,
#  'came': 135,
#  'abandon': 0,
#  'coupl': 209,
#  'met': 534,
#  'befriend': 92,
#  'suggest': 847,
#  'go': 379,
#  'togeth': 894,
#  'shoot': 785,
#  'brutal': 124,
#  'part': 608,
#  'intend': 450,
#  'scare': 752,
#  'catch': 142,
#  'made': 514,
#  'declar': 236,
#  'take': 863,
#  'take place': 864,
#  'place': 628,
#  'one': 589,
#  'say': 751,
#  'put': 679,
#  'gun': 394,
#  'back': 80,
#  'run': 744,
#  'work': 981,
#  'gas': 368,
#  'station': 827,
#  'neighbor': 566,
#  'tell': 875,
#  'got': 384,
#  'suffer': 846,
#  'think': 881,
#  'look': 504,
#  'seen': 766,
#  'provid': 673,
#  'recent': 695,
#  'beg': 93,
#  'turn': 918,
#  'space': 815,
#  'hous': 423,
#  'bodi': 112,
#  'victim': 940,
#  'paper': 606,
#  'confront': 192,
#  'believ': 97,
#  'express': 316,
#  'univers': 933,
#  'whose': 967,
#  'black': 105,
#  'hole': 415,
#  'love': 509,
#  'next': 572,
#  'night': 573,
#  'first': 342,
#  'imprison': 438,
#  'daughter': 229,
#  'arm': 57,
#  'paint': 603,
#  'face': 319,
#  'differ': 252,
#  'direct': 254,
#  'stay': 828,
#  'machin': 512,
#  'rescu': 714,
#  'use': 937,
#  'empti': 284,
#  'live': 499,
#  'reveal': 729,
#  'explos': 314,
#  'fire': 341,
#  'die': 251,
#  'reunit': 728,
#  'talk': 866,
#  'could': 207,
#  'never': 567,
#  'base': 87,
#  'mrs': 553,
#  'class': 164,
#  'frustrat': 361,
#  'idea': 430,
#  'call': 134,
#  'aid': 26,
#  'prostitut': 669,
#  'meet': 527,
#  'fall': 324,
#  'late': 482,
#  'move': 551,
#  'enough': 292,
#  'offer': 583,
#  'servic': 776,
#  'separ': 772,
#  'slowli': 806,
#  'enter': 295,
#  'world': 983,
#  'extrem': 317,
#  'begin': 94,
#  'control': 201,
#  'caus': 144,
#  'pain': 602,
#  'hide': 408,
#  'tabl': 862,
#  'hand': 397,
#  'clear': 166,
#  'cold': 172,
#  'proceed': 659,
#  'crush': 221,
#  'get': 370,
#  'jealous': 463,
#  'know': 476,
#  'much': 554,
#  'hurt': 427,
#  'men': 530,
#  'upset': 935,
#  'also': 36,
#  'sneak': 808,
#  'tie': 891,
#  'buy': 131,
#  'marriag': 520,
#  'dream': 268,
#  'hit': 413,
#  'like': 496,
#  'yet': 996,
#  'restaur': 722,
#  'angri': 42,
#  'throw': 888,
#  'wall': 951,
#  'alcohol': 29,
#  'last': 481,
#  'sex': 780,
#  'thrown': 889,
#  'thus': 890,
#  'though': 883,
#  'stop': 833,
#  'short': 787,
#  'evil': 304,
#  'claim': 163,
#  'fail': 322,
#  'parent': 607,
#  'new': 568,
#  'elder': 280,
#  'old': 587,
#  'carri': 139,
#  'origin': 597,
#  'sign': 792,
#  'time': 892,
#  'good': 383,
#  'draw': 267,
#  'follow': 351,
#  'side': 790,
#  'hard': 401,
#  'girlfriend': 376,
#  'realli': 693,
#  'left': 491,
#  'woman': 978,
#  'reluct': 704,
#  'still': 831,
#  'hang': 398,
#  'come back': 178,
#  'feel': 330,
#  'break': 118,
#  'start': 825,
#  'see': 763,
#  'best': 99,
#  'meanwhil': 525,
#  'affair': 19,
#  'howev': 424,
#  'realis': 691,
#  'final': 337,
#  'attempt': 70,
#  'date': 228,
#  'someth': 813,
#  'pregnant': 650,
#  'friendship': 359,
#  'threaten': 885,
#  'ruin': 742,
#  'inform': 442,
#  'audienc': 74,
#  'lost': 508,
#  'strong': 838,
#  'person': 619,
#  'famili': 325,
#  'play': 633,
#  'role': 739,
#  'sudden': 845,
#  'stage': 823,
#  'disappear': 256,
#  'around': 58,
#  'recogn': 696,
#  'desper': 245,
#  'prove': 672,
#  'robot': 738,
#  'fli': 347,
#  'scientist': 756,
#  'complet': 185,
#  'center': 148,
#  'similar': 793,
#  'line': 497,
#  'front': 360,
#  'monster': 546,
#  'robberi': 737,
#  'right': 733,
#  'announc': 44,
#  'local': 500,
#  'cover': 212,
#  'land': 479,
#  'street': 836,
#  'outsid': 599,
#  'toward': 901,
#  'includ': 440,
#  'flee': 346,
#  'phone': 621,
#  'climb': 167,
#  'emerg': 281,
#  'notic': 576,
#  'gone': 382,
#  'goe': 381,
#  'chang': 150,
#  'cloth': 169,
#  'high': 409,
#  'spot': 820,
#  'insid': 445,
#  'struggl': 839,
#  'surviv': 855,
#  'instead': 448,
#  'demand': 240,
#  'appear': 52,
#  'pull': 675,
#  'knock': 475,
#  'initi': 443,
#  'seem': 765,
#  'beat': 88,
#  'ground': 389,
#  'defeat': 237,
#  'send': 768,
#  'hold': 414,
#  'knife': 474,
#  'cut': 222,
#  'step': 830,
#  'across': 8,
#  'grab': 386,
#  'film end': 336,
#  'shot': 788,
#  'issu': 460,
#  'describ': 242,
#  'adventur': 17,
#  'arrest': 60,
#  'recov': 698,
#  'repli': 711,
#  'thank': 879,
#  'age': 22,
#  'unit': 931,
#  'action': 10,
#  'perform': 618,
#  'band': 85,
#  'watch': 955,
#  'sens': 769,
#  'speak': 816,
#  'introduc': 456,
#  'keep': 466,
#  'ship': 783,
#  'troubl': 916,
#  'distract': 260,
#  'quit': 683,
#  'children': 157,
#  'week': 962,
#  'wish': 973,
#  'engag': 289,
#  'four': 357,
#  'bank': 86,
#  'ask': 62,
#  'father': 327,
#  'help': 406,
#  'damag': 224,
#  'tear': 872,
#  'note': 574,
#  'dark': 227,
#  'respond': 719,
#  'despit': 246,
#  'although': 37,
#  'rule': 743,
#  'employ': 283,
#  'trial': 913,
#  'surpris': 853,
#  'trio': 915,
#  'close': 168,
#  'anim': 43,
#  'ride': 732,
#  'enjoy': 291,
#  'danc': 225,
#  'join': 464,
#  'hors': 418,
#  'pass': 612,
#  'save': 750,
#  'win': 971,
#  'word': 980,
#  'interrupt': 454,
#  'travel': 908,
#  'uncl': 926,
#  'laugh': 484,
#  'parti': 609,
#  'grow': 391,
#  'increas': 441,
#  'stori': 835,
#  'plan': 629,
#  'lack': 478,
#  'order': 595,
#  'mention': 532,
#  'rest': 721,
#  'persuad': 620,
#  'actual': 13,
#  'wait': 948,
#  'protest': 671,
#  'forc': 353,
#  'busi': 130,
#  'guard': 392,
#  'chase': 153,
#  'safe': 748,
#  'problem': 658,
#  'depart': 241,
#  'clean': 165,
#  'mind': 538,
#  'warn': 954,
#  'danger': 226,
#  'activ': 11,
#  'tour': 900,
#  'colleagu': 174,
#  'mistak': 544,
#  'entir': 296,
#  'view': 942,
#  'within': 976,
#  'minut': 541,
#  'mean': 524,
#  'anyth': 48,
#  'immedi': 435,
#  'need': 565,
#  'childhood': 156,
#  'eye': 318,
#  'approach': 53,
#  'apolog': 50,
#  'give': 377,
#  'thing': 880,
#  'accept': 3,
#  'thought': 884,
#  'alon': 33,
#  'build': 126,
#  'sit': 800,
#  'sinc': 794,
#  'loss': 507,
#  'fear': 328,
#  'might': 536,
#  'suicid': 848,
#  'suppli': 850,
#  'window': 972,
#  'charg': 152,
#  'fill': 334,
#  'partner': 611,
#  'done': 263,
#  'write': 988,
#  'condit': 188,
#  'friend': 358,
#  'owner': 600,
#  'nazi': 562,
#  'world war': 984,
#  'war': 953,
#  'near': 563,
#  'american': 39,
#  'area': 54,
#  'sleep': 804,
#  'top': 897,
#  'share': 782,
#  'yearold': 995,
#  'divorc': 261,
#  'search': 758,
#  'wife': 969,
#  'social': 809,
#  'convinc': 203,
#  'sight': 791,
#  'steal': 829,
#  'villag': 943,
#  'career': 138,
#  'big': 102,
#  'director': 255,
#  'skill': 803,
#  'success': 844,
#  'news': 570,
#  'year ago': 992,
#  'ago': 24,
#  'reach': 688,
#  'request': 713,
#  'realiz': 692,
#  'countri': 208,
#  'confus': 193,
#  'mother': 548,
#  'los': 505,
#  'spend': 817,
#  'spend time': 818,
#  'respons': 720,
#  'result': 723,
#  'avoid': 77,
#  'continu': 199,
#  'cheat': 154,
#  'argument': 56,
#  'lock': 502,
#  'gangster': 367,
#  'state': 826,
#  'rape': 686,
#  'push': 678,
#  'day': 230,
#  'effort': 279,
#  'kick': 467,
#  'apart': 49,
#  'card': 137,
#  'ignor': 433,
#  'everyth': 302,
#  'refus': 699,
#  'prepar': 651,
#  'commit suicid': 181,
#  'protect': 670,
#  'afterward': 21,
#  'get marri': 372,
#  'third': 882,
#  'behind': 96,
#  'expect': 309,
#  'would': 986,
#  'someon': 812,
#  'betray': 100,
#  'taken': 865,
#  'bring': 120,
#  'subsequ': 842,
#  'alreadi': 35,
#  'arrang': 59,
#  'reject': 700,
#  'hire': 411,
#  'number': 578,
#  'settl': 778,
#  'professor': 662,
#  'cell': 147,
#  'offici': 585,
#  'captur': 136,
#  'inspector': 447,
#  'colleg': 176,
#  'guest': 393,
#  'writer': 989,
#  'drink': 270,
#  'investig': 457,
#  'develop': 250,
#  'transform': 905,
#  'full': 362,
#  'way': 957,
#  'touch': 899,
#  'past': 614,
#  'student': 840,
#  'punish': 676,
#  'led': 490,
#  'let': 493,
#  'succeed': 843,
#  'mental': 531,
#  'plant': 632,
#  'bomb': 113,
#  'repeat': 709,
#  'road': 736,
#  'orphan': 598,
#  'studi': 841,
#  'agre': 25,
#  'titl': 893,
#  'teenag': 873,
#  'ident': 431,
#  'letter': 494,
#  'alway': 38,
#  'youth': 997,
#  'advanc': 16,
#  'dr': 265,
#  'due': 275,
#  'lover': 510,
#  'mad': 513,
#  'read': 689,
#  'decis': 235,
#  'prevent': 654,
#  'emot': 282,
#  'impress': 437,
#  'understand': 928,
#  'hear': 403,
#  'locat': 501,
#  'nativ': 561,
#  'incid': 439,
#  'went': 964,
#  'three': 886,
#  'month': 547,
#  'shock': 784,
#  'charact': 151,
#  'told': 895,
#  'mountain': 549,
#  'compani': 183,
#  'lose': 506,
#  'accid': 4,
#  'bus': 129,
#  'rather': 687,
#  'worri': 985,
#  'year old': 994,
#  'readi': 690,
#  'high school': 410,
#  'school': 755,
#  'happen': 399,
#  'group': 390,
#  'teacher': 870,
#  'longer': 503,
#  'gang': 366,
#  'strike': 837,
#  'girl': 375,
#  'shop': 786,
#  'ultim': 923,
#  'cop': 204,
#  'suspect': 857,
#  'stolen': 832,
#  'aunt': 75,
#  'present': 652,
#  'far': 326,
#  'execut': 307,
#  'member': 528,
#  'messag': 533,
#  'older': 588,
#  'relat': 701,
#  'desert': 243,
#  'glass': 378,
#  'expos': 315,
#  'properti': 667,
#  'anger': 41,
#  'encount': 285,
#  'plot': 635,
#  'former': 355,
#  'newspap': 571,
#  'pursu': 677,
#  'govern': 385,
#  'assist': 66,
#  'design': 244,
#  'often': 586,
#  'sentenc': 771,
#  'teach': 869,
#  'soldier': 811,
#  'terrorist': 876,
#  'pair': 604,
#  'match': 522,
#  'opportun': 594,
#  'brother': 122,
#  'rival': 735,
#  'nation': 560,
#  'back home': 81,
#  'lure': 511,
#  'drug': 273,
#  'affect': 20,
#  'whole': 966,
#  'pay': 616,
#  'leg': 492,
#  'better': 101,
#  'japanes': 462,
#  'crowd': 220,
#  'rais': 685,
#  'run away': 745,
#  'kidnap': 469,
#  'ring': 734,
#  'process': 660,
#  'noth': 575,
#  'swim': 859,
#  'almost': 32,
#  'answer': 46,
#  'hair': 395,
#  'serv': 774,
#  'particular': 610,
#  'scream': 757,
#  'occur': 582,
#  'secur': 761,
#  'hope': 417,
#  'competit': 184,
#  'dinner': 253,
#  'quiet': 682,
#  'experi': 310,
#  'practic': 649,
#  'photograph': 623,
#  'among': 40,
#  'patient': 615,
#  'suspici': 858,
#  'financi': 338,
#  'credit': 216,
#  'appar': 51,
#  'situat': 801,
#  'instruct': 449,
#  'go back': 380,
#  'assault': 64,
#  'convers': 202,
#  'confess': 189,
#  'accompani': 6,
#  'cours': 210,
#  'form': 354,
#  'focus': 350,
#  'conflict': 191,
#  'polit': 640,
#  'minist': 540,
#  'unit state': 932,
#  'support': 851,
#  'remov': 708,
#  'insist': 446,
#  'found': 356,
#  'video': 941,
#  'launch': 485,
#  'twin': 920,
#  'intern': 453,
#  'featur': 329,
#  'game': 365,
#  'televis': 874,
#  'player': 634,
#  'crash': 213,
#  'retir': 724,
#  'new citi': 569,
#  'mansion': 518,
#  'drive': 271,
#  'boy': 116,
#  'sexual': 781,
#  'prompt': 666,
#  'ball': 84,
#  'effect': 278,
#  'contact': 197,
#  'organ': 596,
#  'communiti': 182,
#  'resid': 716,
#  'nurs': 579,
#  'everyon': 301,
#  'six': 802,
#  'tri get': 912,
#  'tv': 919,
#  'violent': 944,
#  'photo': 622,
#  'explor': 313,
#  'test': 877,
#  'mission': 543,
#  'challeng': 149,
#  'interview': 455,
#  'two men': 922,
#  'attent': 72,
#  'unexpect': 929,
#  'accus': 7,
#  'dead': 231,
#  'narrat': 559,
#  'contain': 198,
#  'fellow': 331,
#  'cave': 145,
#  'giant': 374,
#  'engin': 290,
#  'quick': 681,
#  'anyon': 47,
#  'wit': 974,
#  'discuss': 258,
#  'funer': 363,
#  'aliv': 30,
#  'determin': 249,
#  'caught': 143,
#  'board': 110,
#  'admit': 14,
#  'worker': 982,
#  'slip': 805,
#  'hour': 422,
#  'water': 956,
#  'food': 352,
#  'evid': 303,
#  'drop': 272,
#  'hidden': 407,
#  'object': 580,
#  'known': 477,
#  'secret': 760,
#  'brought': 123,
#  'pictur': 626,
#  'cri': 217,
#  'spi': 819,
#  'associ': 67,
#  'enemi': 288,
#  'identifi': 432,
#  'import': 436,
#  'propos': 668,
#  'fake': 323,
#  'research': 715,
#  'pretend': 653,
#  'bed': 91,
#  'kiss': 473,
#  'agent': 23,
#  'crime': 218,
#  'ill': 434,
#  'sister': 799,
#  'blood': 108,
#  'onto': 591,
#  'floor': 349,
#  'crimin': 219,
#  'truck': 917,
#  'year later': 993,
#  'disguis': 259,
#  'whether': 965,
#  'sell': 767,
#  'belong': 98,
#  'memori': 529,
#  'mask': 521,
#  'mysteri': 557,
#  'connect': 194,
#  'plane': 630,
#  'bad': 82,
#  'injur': 444,
#  'unabl': 924,
#  'explod': 312,
#  'actor': 12,
#  'corrupt': 206,
#  'accident': 5,
#  'collect': 175,
#  'passeng': 613,
#  'us': 936,
#  'track': 903,
#  'creatur': 215,
#  'argu': 55,
#  'defend': 238,
#  'resist': 717,
#  'grandfath': 387,
#  'public': 674,
#  'helicopt': 405,
#  'eat': 277,
#  'gain': 364,
#  'remind': 707,
#  'abus': 2,
#  'hostag': 420,
#  'promis': 664,
#  'stand': 824,
#  'enrag': 293,
#  'drag': 266,
#  'popular': 642,
#  'histori': 412,
#  'huge': 425,
#  'wed': 961,
#  'unawar': 925,
#  'encourag': 286,
#  'power': 648,
#  'poor': 641,
#  'cite': 160,
#  'cite web': 161,
#  'web': 960,
#  'club': 170,
#  'suppos': 852,
#  'drunk': 274,
#  'birthday': 104,
#  'produc': 661,
#  'kind': 472,
#  'behavior': 95,
#  'obsess': 581,
#  'project': 663,
#  'blind': 107,
#  'fish': 343,
#  'bug': 125,
#  'took': 896,
#  'mous': 550,
#  'trap': 907,
#  'respect': 718,
#  'cousin': 211,
#  'servant': 775,
#  'reveng': 730,
#  'rush': 746,
#  'gave': 369,
#  'wrong': 990,
#  'advic': 18,
#  'exchang': 306,
#  'piec': 627,
#  'corps': 205,
#  'bag': 83,
#  'pose': 643,
#  'target': 868,
#  'stab': 821,
#  'assassin': 63,
#  'contract': 200,
#  'broken': 121,
#  'boat': 111,
#  'happili': 400,
#  'dad': 223,
#  'sing': 795,
#  'factori': 321,
#  'record': 697,
#  'singer': 796,
#  'trick': 914,
#  'vow': 947,
#  'widow': 968,
#  'check': 155,
#  'birth': 103,
#  'moment': 545,
#  'main': 515,
#  'radio': 684,
#  'seek': 764,
#  'attend': 71,
#  'promot': 665,
#  'hotel': 421,
#  'celebr': 146,
#  'book': 114,
#  'tape': 867,
#  'listen': 498,
#  'voic': 946,
#  '—': 999,
#  'five': 344,
#  'middl': 535,
#  'get back': 371,
#  'store': 834,
#  'jump': 465,
#  'retriev': 725,
#  'consid': 195,
#  'dog': 262,
#  'exist': 308,
#  'estat': 298,
#  'adopt': 15,
#  'matter': 523,
#  'nearbi': 564,
#  'scheme': 754,
#  'unconsci': 927,
#  'grandmoth': 388,
#  'pack': 601,
#  'ice': 429,
#  'cat': 141,
#  'burn': 128,
#  'attract': 73,
#  'militari': 537,
#  'invit': 458,
#  'wound': 987,
#  'weapon': 958,
#  'revolv': 731,
#  'safeti': 749,
#  'collaps': 173,
#  'chines': 158,
#  'box': 115,
#  'vampir': 938,
#  'one night': 590,
#  'lie': 495,
#  'wake': 949,
#  'surround': 854,
#  'singh': 797,
#  'coach': 171,
#  'confid': 190,
#  'dress': 269,
#  'flight': 348,
#  'th': 878,
#  'staff': 822,
#  'tree': 910,
#  'cast': 140,
#  'russian': 747,
#  'except': 305,
#  'palac': 605,
#  'physic': 624,
#  'deal': 232,
#  'comput': 186,
#  'singl': 798,
#  'tortur': 898,
#  'awaken': 78,
#  'rememb': 706,
#  'abil': 1,
#  'poison': 637,
#  'assign': 65,
#  'witch': 975,
#  'buri': 127,
#  'post': 647,
#  'kid': 468,
#  'medic': 526,
#  'figur': 333,
#  'ca': 132,
#  'ca nt': 133,
#  'sword': 860,
#  'privat': 657,
#  'assum': 68,
#  'treat': 909,
#  'wild': 970,
#  'choos': 159,
#  'construct': 196,
#  'becam': 89,
#  'replac': 710,
#  'zombi': 998,
#  'airport': 28}

# %%
tfidf_summ.shape
# Out:
# (42303, 1000)

# %%
words = np.array(tfidf.get_feature_names())

# %%
nmf = NMF(
    100
)
nmf_words = nmf.fit_transform(tfidf_summ.T)
print("NMF Shape: %d words x %d categories" % nmf_words.shape)
# Out:
# (1000, 100)

# %%
n_words = 10
for i in range(nmf.n_components):
    print(f"Topic {i:2d}: " + ", ".join(words[nmf_words[:,i].argsort()[::-1][:n_words]] ))
# Out:
# Topic  0: tri, tri get, keep, save, convinc, stop, fail, desper, meanwhil, struggl
# Topic  1: escap, plan, attempt, captur, discov, rescu, howev, manag, arriv, reveal
# Topic  2: film, follow, director, scene, featur, base, interview, narrat, includ, film end
# Topic  3: marriag, arrang, wed, propos, accept, agre, love, divorc, engag, also
# Topic  4: murder, investig, detect, suspect, crime, wit, accus, found, evid, involv
# Topic  5: school, high school, high, teacher, class, student, attend, board, teach, miss
# Topic  6: villag, small, mountain, land, nativ, teacher, return, water, fish, reach
# Topic 92: hors, ride, win, wild, buy, owner, sell, anim, give, black
# Topic 93: compani, busi, owner, hire, sell, rival, partner, worker, financi, execut
# Topic 94: danc, perform, club, stage, sing, competit, singer, act, audienc, night
# Topic 95: forc, plane, land, bomb, fli, base, mission, air, flight, terrorist
# Topic 96: decid, go, howev, stay, start, let, give, realiz, girlfriend, go back
# Topic 97: dr, patient, hospit, scientist, medic, experi, nurs, mental, research, assist
# Topic 98: bank, robberi, plan, crimin, hostag, stolen, manag, steal, crime, gun
# Topic 99: charact, book, plot, main, around, revolv, includ, involv, seri, writer

# %%
nmf_words = pd.Series(
    [", ".join(words[nmf_words[:,i].argsort()[::-1][:n_words]]) for i in range(nmf.n_components)]
)
nmf_words.head()
# Out:
# 0    tri, tri get, keep, save, convinc, stop, fail,...
# 1    escap, plan, attempt, captur, discov, rescu, h...
# 2    film, follow, director, scene, featur, base, i...
# 3    marriag, arrang, wed, propos, accept, agre, lo...
# 4    murder, investig, detect, suspect, crime, wit,...
# dtype: object

# %%
import re

# %%
nmf_words[nmf_words.apply(re.compile(r"[^,] ").search).notna()]
# Out:
# 0     tri, tri get, keep, save, convinc, stop, fail,...
# 2     film, follow, director, scene, featur, base, i...
# 5     school, high school, high, teacher, class, stu...
# 9     cite, web, cite web, news, base, book, travel,...
# 13    polic, inspector, arrest, crimin, polic offic,...
# 15    come, know, come back, start, across, also, lo...
# 17    war, world war, nazi, second, resist, join, co...
# 26    back, bring, go, get back, come back, go back,...
# 32    new, new citi, move, career, learn, includ, me...
# 34    year, old, year old, year later, later, ago, y...
# 37    end, film end, eventu, final, turn, first, wel...
# 41    home, return, return home, back home, visit, a...
# 46    men, two men, four, gun, shoot, shot, wound, o...
# 48    take, place, take place, reveng, part, turn, a...
# 49    get, start, goe, get marri, tri get, thing, tr...
# 52    one, night, one night, anoth, last, seem, pers...
# 55    citi, new citi, big, street, build, search, lo...
# 56    two, two men, togeth, sister, lover, differ, s...
# 62    parent, adopt, teenag, divorc, away, yearold, ...
# 63    time, spend, first, spend time, much, final, p...
# 66    unit, state, unit state, us, govern, polit, na...
# 68    suicid, commit, commit suicid, crime, attempt,...
# 71    world, world war, evil, must, around, adventur...
# 78    offic, polic offic, command, former, corrupt, ...
# 84    marri, get marri, wed, love, happili, howev, d...
# 86    nt, want, ca, ca nt, know, think, say, go, thi...
# 96    decid, go, howev, stay, start, let, give, real...
# dtype: object

# %%
nmf_labels = pd.Series(
    nmf.components_.argmax(0)
)
nmf_labels.head()
# Out:
# 0    11
# 1    27
# 2    15
# 3    34
# 4    20
# dtype: int64

# %%
nmf_movies = pd.DataFrame({
    "category": nmf_labels,
    "label": nmf_words.iloc[nmf_labels].reset_index(drop=True),
    "title": summary_df.title,
    "summary": summary_df['summary']
}).sort_values("category")
nmf_movies.head()
# Out:
#        category                                              label  \
# 19290         0  tri, tri get, keep, save, convinc, stop, fail,...
# 38228         0  tri, tri get, keep, save, convinc, stop, fail,...
# 5775          0  tri, tri get, keep, save, convinc, stop, fail,...
# 5771          0  tri, tri get, keep, save, convinc, stop, fail,...
# 29146         0  tri, tri get, keep, save, convinc, stop, fail,...
#
#                        title  \
# 19290  Calendar Girl Murders
# 38228          Dil Ka Rishta
# 5775                Penelope
# 5771            Five Fingers
# 29146      I Can Hardly Wait
#
#                                                  summary
# 19290  The plot revolves around the relationship betw...
# 38228  Dil Ka Rishta is about a young man named Jai ....
# 5775   {{plot}} Penelope Elcott  is the wife of wealt...
# 5771   Martijn , a gifted Dutch jazz pianist, flies t...
# 29146  The Stooges, who are defense workers, prepare ...

# %%
nmf_movies.groupby("category").head(5)
# Out:
#        category                                              label  \
# 19290         0  tri, tri get, keep, save, convinc, stop, fail,...
# 38228         0  tri, tri get, keep, save, convinc, stop, fail,...
# 5775          0  tri, tri get, keep, save, convinc, stop, fail,...
# 5771          0  tri, tri get, keep, save, convinc, stop, fail,...
# 29146         0  tri, tri get, keep, save, convinc, stop, fail,...
# 27270         1  escap, plan, attempt, captur, discov, rescu, h...
# 32073         1  escap, plan, attempt, captur, discov, rescu, h...
# 22041         1  escap, plan, attempt, captur, discov, rescu, h...
# 34195         1  escap, plan, attempt, captur, discov, rescu, h...
# 41676         1  escap, plan, attempt, captur, discov, rescu, h...
# 25405         2  film, follow, director, scene, featur, base, i...
# 11623         2  film, follow, director, scene, featur, base, i...
# 10589         2  film, follow, director, scene, featur, base, i...
# 12112         2  film, follow, director, scene, featur, base, i...
# 9977          2  film, follow, director, scene, featur, base, i...
# 36976         3  marriag, arrang, wed, propos, accept, agre, lo...
# 3512          3  marriag, arrang, wed, propos, accept, agre, lo...
# 35046         3  marriag, arrang, wed, propos, accept, agre, lo...
# 8782          3  marriag, arrang, wed, propos, accept, agre, lo...
# 36902         3  marriag, arrang, wed, propos, accept, agre, lo...
# 19652         4  murder, investig, detect, suspect, crime, wit,...
# 14625         4  murder, investig, detect, suspect, crime, wit,...
# 13842         4  murder, investig, detect, suspect, crime, wit,...
# 34810         4  murder, investig, detect, suspect, crime, wit,...
# 7901          4  murder, investig, detect, suspect, crime, wit,...
# 14772         5  school, high school, high, teacher, class, stu...
# 20285         5  school, high school, high, teacher, class, stu...
# 38136         5  school, high school, high, teacher, class, stu...
# 37848         5  school, high school, high, teacher, class, stu...
# 29590         5  school, high school, high, teacher, class, stu...
# ...         ...                                                ...
# 40030        93  compani, busi, owner, hire, sell, rival, partn...
# 16399        94  danc, perform, club, stage, sing, competit, si...
# 33737        94  danc, perform, club, stage, sing, competit, si...
# 28905        94  danc, perform, club, stage, sing, competit, si...
# 22220        94  danc, perform, club, stage, sing, competit, si...
# 12648        94  danc, perform, club, stage, sing, competit, si...
# 29267        95  forc, plane, land, bomb, fli, base, mission, a...
# 38855        95  forc, plane, land, bomb, fli, base, mission, a...
# 19759        95  forc, plane, land, bomb, fli, base, mission, a...
# 33087        95  forc, plane, land, bomb, fli, base, mission, a...
# 12372        95  forc, plane, land, bomb, fli, base, mission, a...
# 39027        96  decid, go, howev, stay, start, let, give, real...
# 6403         96  decid, go, howev, stay, start, let, give, real...
# 20414        96  decid, go, howev, stay, start, let, give, real...
# 31020        96  decid, go, howev, stay, start, let, give, real...
# 29156        97  dr, patient, hospit, scientist, medic, experi,...
# 27022        97  dr, patient, hospit, scientist, medic, experi,...
# 24128        97  dr, patient, hospit, scientist, medic, experi,...
# 23549        97  dr, patient, hospit, scientist, medic, experi,...
# 15633        97  dr, patient, hospit, scientist, medic, experi,...
# 24550        98  bank, robberi, plan, crimin, hostag, stolen, m...
# 38800        98  bank, robberi, plan, crimin, hostag, stolen, m...
# 23285        98  bank, robberi, plan, crimin, hostag, stolen, m...
# 31552        98  bank, robberi, plan, crimin, hostag, stolen, m...
# 6571         98  bank, robberi, plan, crimin, hostag, stolen, m...
# 35028        99  charact, book, plot, main, around, revolv, inc...
# 7588         99  charact, book, plot, main, around, revolv, inc...
# 40307        99  charact, book, plot, main, around, revolv, inc...
# 19740        99  charact, book, plot, main, around, revolv, inc...
# 40556        99  charact, book, plot, main, around, revolv, inc...
#
#                                                    title  \
# 19290                              Calendar Girl Murders
# 38228                                      Dil Ka Rishta
# 5775                                            Penelope
# 5771                                        Five Fingers
# 29146                                  I Can Hardly Wait
# 27270                    Highlander: The Final Dimension
# 32073  Naruto the Movie: Snow Princess' Book of Ninja...
# 22041                                            Rob Roy
# 34195                       The Lives of a Bengal Lancer
# 41676                               British Intelligence
# 25405                                         Twenty-One
# 11623                                               Tube
# 10589                                          The Falls
# 12112                         The Other Side of the Wind
# 9977                           Death Bell 2: Bloody Camp
# 36976                              Sense and Sensibility
# 3512                                          Kalem Mama
# 35046                               Around the Boree Log
# 8782                           The Girl from 10th Avenue
# 36902                                             Kushti
# 19652                                       Saint Sinner
# 14625                             Shadows Over Chinatown
# 13842                                             Wanted
# 34810                           Charlie Chan in Honolulu
# 7901                                     Mortal Transfer
# 14772                                           Case 219
# 20285                            The Bells of St. Mary's
# 38136                                     The First Time
# 37848           A Greater Yes: The Story of Amy Newhouse
# 29590                                        Coming Soon
# ...                                                  ...
# 40030                                       Breakthrough
# 16399                           Jhanak Jhanak Payal Baje
# 33737                                               Rize
# 28905                                      Dancing Romeo
# 22220                  Does the Jazz Lead to Destruction
# 12648                                    Graffiti Bridge
# 29267                         The World Owes Me a Living
# 38855                                  Snakes on a Plane
# 19759                            Tarzan's Deadly Silence
# 33087                              The Great Who-Dood-It
# 12372                           Die Stunde der Offiziere
# 39027                                    Value for Money
# 6403                                            The Crop
# 20414                                               Davy
# 31020                                     Lady Libertine
# 29156                            The Crime of Dr. Crespi
# 27022                                            Spymate
# 24128                                       Mosquito Man
# 23549                                      Bhagavad Gita
# 15633                          The Abominable Dr. Phibes
# 24550                         A Man, a Woman, and a Bank
# 38800                                          Fall Time
# 23285                                        Ghanchakkar
# 31552                              Banking Hours 10 to 4
# 6571                                    Ocean's Thirteen
# 35028                                    Lathe of Heaven
# 7588                                            Rezerwat
# 40307                                Teddy boy agapi mou
# 19740                    Kōichirō Uno's Wet and Swinging
# 40556                              Chilbeontong sosageon
#
#                                                  summary
# 19290  The plot revolves around the relationship betw...
